# %% [markdown]
#  Question 2
# Implement Gradient Descent in a Jupyter Notebook. Also explain in the same file how tuning each hyperparameter changes the outcome?

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)

# Preprocessing Input data
 
X = np.array([1,2,3,4,5])
Y = np.array([3,5,7,9,11])
plt.scatter(X, Y)
plt.show()

# %%
# linear regression 
m = 0
c = 0
x= []
pred=[]
L = 0.0001  # The learning Rate
epochs = 10000 # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    pred.append(m)
    x.append(i)
print (m, c)
plt.plot(x,pred)
plt.xlabel('iterations')
plt.ylabel('value of m/slope')
# print (pred)
# Out:
# 2.0818242597888412 0.7045884590420965
# Text(0, 0.5, 'value of m/slope')

# %%
# Making predictions

Y_pred = m*X + c

plt.scatter(X, Y)
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red') # predicted
plt.show()

# %%
 # linear regression 
m = 0
c = 0
x= []
pred=[]
L = 1 # The learning Rate
epochs = 10 # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    pred.append(m)
    x.append(i)
print (m, c)
plt.plot(x,pred)
plt.xlabel('iterations')
plt.ylabel('value of m/slope')
# print (pred)
# Out:
# -75547667338924.0 -20925492442140.0
# Text(0, 0.5, 'value of m/slope')

# %% [markdown]
# if we take the hyper tuning parameter to be quite then even thogh the iterations are low the value of the parameters cross the expected value and does not seem to return for large values we cant go for more iterations as thw values become too large .

# %%
# linear regression 
m = 0
c = 0
x= []
pred=[]
L = 0.0000001  # The learning Rate
epochs = 10000 # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    pred.append(m)
    x.append(i)
print (m, c)
plt.plot(x,pred)
plt.xlabel('iterations')
plt.ylabel('value of m/slope')
# print (pred)
# Out:
# 0.049412699657934316 0.01383730173530969
# Text(0, 0.5, 'value of m/slope')

# %% [markdown]
# for very small hypertuning values we are not able to reach the minimum we would need a lot more iterations

# %% [markdown]
# Question 3
# Go through first 2 chapters of ISLR. Now, explain Bias-Variance tradeoff in detail.

# %% [markdown]
# BIAS:
#
# A model with low bias will make fewer assumptions about the target function, and will perform better on training data.
#
# A model with a low bias is preffered. This means that it effectively captures all the data in the feature space, and is able to fit well on training data.
# A model with low bias will perform very well on the training set,lo error on training data.
# Simple models (like linear models) have higher bias. They don't fit very well onto the training set.
# complex functions  tend to have lower bias, and fit very well on training data.
#
# VARIANCE:
#
# A model's variance is the amount by which the its prediction would vary if a different training set was used.
#  we want the  the model's predictions  not vary too much.
# If the model has picked up on underlying patterns and is able to correctly identify relationships between variables, then its variance should be low.
#
#
#
# An ideal machine learning model should have low bias and low variance. This model should perform well on the training dataset by identifying relationships between variables and making fewer assumptions.
#
# At the same time, the model needs to be able to generalize, and should perform well on data that its never seen before.
#
# As the bias of the model increases, its variance decreases.
